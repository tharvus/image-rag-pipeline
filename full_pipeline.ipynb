# %%
from qdrant_client import QdrantClient
from qdrant_client.http.models import Filter, FieldCondition, MatchValue
from qdrant_client.models import Distance, VectorParams, PointStruct
from tqdm import tqdm

from sklearn.metrics.pairwise import cosine_similarity, cosine_distances
from scipy.sparse import csgraph
from sklearn.manifold import SpectralEmbedding
from sklearn.preprocessing import normalize

import numpy as np
import torch
from PIL import Image
import os
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D

from pathlib import Path
import re

#importing the used models
from transformers import AutoTokenizer, CLIPModel, AutoProcessor, CLIPConfig, CLIPTokenizer, CLIPProcessor

from utils.metrics import iterate_ds, mean_reciprocal_rank, recall_at_k

# %% [markdown]
# # Step 1: Read in Short generated captions CSV with image paths installed locally

# %%
df_s_captions = pd.read_csv("./short_generated_captions.csv")

# %%
df_s_captions.head()
# Out:
#    id                                            img_url  \
# 0   1  https://thumbs.dreamstime.com/b/car-riding-wet...
# 1   2  https://images.pexels.com/photos/770224/pexels...
# 2   3  https://filmfare.wwmindia.com/content/2017/jul...
# 3   4  https://southernersays.com/wp-content/uploads/...
# 4   5  https://i.pinimg.com/originals/9a/f5/a6/9af5a6...
#
#                                     original_caption  \
# 0  Car riding on wet street. Car driving on wet c...
# 1                         Water Coming Out Of A Pipe
# 2  MARCH 2009 ''It's sad that a boy and girl can ...
# 3         Humpback Whale tail in the Bay of Banderas
# 4  The gaming Team logo of team DUO Team Logo, My...
#
#                                  paraphrased_caption
# 0            Vehicle driving on a rainy city street.
# 1                        Water spilling from a pipe.
# 2  MARCH 2009 'It's unfortunate that a boy and gi...
# 3            Humpback whale fin in the Banderas Bay.
# 4      DUO Team logo design featuring gaming themes.

# %%
len(df_s_captions)
# Out:
# 499

# %% [markdown]
# ## Retrieve each image path using ids column

# %%
ids = df_s_captions["id"]

# %%
df_s_captions[:20]
# Out:
#     id                                            img_url  \
# 0    1  https://thumbs.dreamstime.com/b/car-riding-wet...
# 1    2  https://images.pexels.com/photos/770224/pexels...
# 2    3  https://filmfare.wwmindia.com/content/2017/jul...
# 3    4  https://southernersays.com/wp-content/uploads/...
# 4    5  https://i.pinimg.com/originals/9a/f5/a6/9af5a6...
# 5    6  https://themaydan.com/wp-content/uploads/2019/...
# 6    7  https://i.pinimg.com/originals/ae/f4/f3/aef4f3...
# 7    8  https://photogallery.indiatimes.com/photo/6551...
# 8    9  https://images.squarespace-cdn.com/content/v1/...
# 9   10  https://slideplayer.com/slide/13821916/85/imag...
# 10  11  https://www.theperspective.com/wp-content/uplo...
# 11  12  https://s.hdnux.com/photos/22/77/21/4977788/3/...
# 12  13  https://static.spotapps.co/spots/b3/140e758769...
# 13  14  https://a.1stdibscdn.com/early-19th-century-ma...
# 14  15  https://thumbs.dreamstime.com/b/waving-flag-ma...
# 15  16  https://images.squarespace-cdn.com/content/v1/...
# 16  17  https://images.squarespace-cdn.com/content/v1/...
# 17  18  https://i.pinimg.com/originals/c3/d3/cc/c3d3cc...
# 18  19         https://wallpapercave.com/wp/wp4839342.jpg
# 19  20  https://image.shutterstock.com/image-vector/no...
#
#                                      original_caption  \
# 0   Car riding on wet street. Car driving on wet c...
# 1                          Water Coming Out Of A Pipe
# 2   MARCH 2009 ''It's sad that a boy and girl can ...
# 3          Humpback Whale tail in the Bay of Banderas
# 4   The gaming Team logo of team DUO Team Logo, My...
# 5   Tea, chilies, and takeaway: what food choices ...
# 6   The Bath Co. Camberley satin grey vanity unit ...
# 7           Celebs attend the launch of a style store
# 8   Europe always amazes me on how well their arch...
# 9                        The Development of the Court
# 10  Skyscrapers in which businesses lead the count...
# 11  A night view of San Francisco's Chinatown in t...
# 12     Restaurant exterior, guests sitting at the bar
# 13  This Ironstone pottery dinner plate was made b...
# 14  Waving flag of Vietnam made of text symbols on...
# 15  Teal Ballerinas for The Teal Recovery Charity ...
# 16  Balloon Mantle for for the Prophet <PERSON>'s ...
# 17  A modern drinks trolley with a lower shelf, cr...
# 18   Wallpapers dog, chic, the cavalier king <PERSON>
# 19  No jump sign vector design for advertising in ...
#
#                                   paraphrased_caption
# 0             Vehicle driving on a rainy city street.
# 1                         Water spilling from a pipe.
# 2   MARCH 2009 'It's unfortunate that a boy and gi...
# 3             Humpback whale fin in the Banderas Bay.
# 4       DUO Team logo design featuring gaming themes.
# 5   Tea, chilies, and takeout: insights into Briti...
# 6   The Bath Co. Camberley satin grey vanity unit ...
# 7   Celebrities grace the opening of a fashion store.
# 8   I'm always impressed by how Europe's architect...
# 9                          The Evolution of the Court
# 10       Skyscrapers that drive the nation's economy.
# 11  A nighttime scene of Chinatown in San Francisc...
# 12  Exterior of a restaurant with patrons seated a...
# 13  This dinner plate made of Ironstone pottery or...
# 14  Computer-generated waving flag of Vietnam crea...
# 15  Teal Ballerinas for The Teal Recovery Charity ...
# 16  Decorative Balloon Mantle for the Prophet's Bi...
# 17  A contemporary drinks trolley featuring an acr...
# 18  Chic wallpaper featuring a Cavalier King Charl...
# 19  Vector design of a no-jump sign for luxury hot...

# %%
ids
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 494    495
# 495    496
# 496    497
# 497    498
# 498    499
# Name: id, Length: 499, dtype: int64

# %% [markdown]
# Now, we use these ids to search for images to get all relevant images for each path. The format of image paths is `img_{id}`

# %%
valid_img_paths = [f'./images/img_{id}.jpg' for id in ids]

# %%
valid_img_paths
# Out:
# ['./images/img_1.jpg',
#  './images/img_2.jpg',
#  './images/img_3.jpg',
#  './images/img_4.jpg',
#  './images/img_5.jpg',
#  './images/img_6.jpg',
#  './images/img_7.jpg',
#  './images/img_8.jpg',
#  './images/img_9.jpg',
#  './images/img_10.jpg',
#  './images/img_11.jpg',
#  './images/img_12.jpg',
#  './images/img_13.jpg',
#  './images/img_14.jpg',
#  './images/img_15.jpg',
#  './images/img_16.jpg',
#  './images/img_17.jpg',
#  './images/img_18.jpg',
#  './images/img_19.jpg',
#  './images/img_20.jpg',
#  './images/img_21.jpg',
#  './images/img_22.jpg',
#  './images/img_23.jpg',
#  './images/img_24.jpg',
#  './images/img_25.jpg',
#  './images/img_26.jpg',
#  './images/img_27.jpg',
#  './images/img_28.jpg',
#  './images/img_29.jpg',
#  './images/img_30.jpg',
#  './images/img_31.jpg',
#  './images/img_32.jpg',
#  './images/img_33.jpg',
#  './images/img_34.jpg',
#  './images/img_35.jpg',
#  './images/img_36.jpg',
#  './images/img_37.jpg',
#  './images/img_38.jpg',
#  './images/img_39.jpg',
#  './images/img_40.jpg',
#  './images/img_41.jpg',
#  './images/img_42.jpg',
#  './images/img_43.jpg',
#  './images/img_387.jpg',
#  './images/img_388.jpg',
#  './images/img_389.jpg',
#  './images/img_390.jpg',
#  './images/img_391.jpg',
#  './images/img_392.jpg',
#  './images/img_393.jpg',
#  './images/img_394.jpg',
#  './images/img_395.jpg',
#  './images/img_396.jpg',
#  './images/img_397.jpg',
#  './images/img_398.jpg',
#  './images/img_399.jpg',
#  './images/img_400.jpg',
#  './images/img_401.jpg',
#  './images/img_402.jpg',
#  './images/img_403.jpg',
#  './images/img_404.jpg',
#  './images/img_405.jpg',
#  './images/img_406.jpg',
#  './images/img_407.jpg',
#  './images/img_408.jpg',
#  './images/img_409.jpg',
#  './images/img_410.jpg',
#  './images/img_411.jpg',
#  './images/img_412.jpg',
#  './images/img_413.jpg',
#  './images/img_414.jpg',
#  './images/img_415.jpg',
#  './images/img_416.jpg',
#  './images/img_417.jpg',
#  './images/img_418.jpg',
#  './images/img_419.jpg',
#  './images/img_420.jpg',
#  './images/img_421.jpg',
#  './images/img_422.jpg',
#  './images/img_423.jpg',
#  './images/img_424.jpg',
#  './images/img_425.jpg',
#  './images/img_426.jpg',
#  './images/img_427.jpg',
#  './images/img_428.jpg',
#  './images/img_429.jpg',
#  './images/img_430.jpg',
#  './images/img_431.jpg',
#  './images/img_432.jpg',
#  './images/img_433.jpg',
#  './images/img_434.jpg',
#  './images/img_435.jpg',
#  './images/img_436.jpg',
#  './images/img_437.jpg',
#  './images/img_438.jpg',
#  './images/img_439.jpg',
#  './images/img_440.jpg',
#  './images/img_441.jpg',
#  './images/img_442.jpg',
#  './images/img_443.jpg',
#  './images/img_444.jpg',
#  './images/img_445.jpg',
#  './images/img_446.jpg',
#  './images/img_447.jpg',
#  './images/img_448.jpg',
#  './images/img_449.jpg',
#  './images/img_450.jpg',
#  './images/img_451.jpg',
#  './images/img_452.jpg',
#  './images/img_453.jpg',
#  './images/img_454.jpg',
#  './images/img_455.jpg',
#  './images/img_456.jpg',
#  './images/img_457.jpg',
#  './images/img_458.jpg',
#  './images/img_459.jpg',
#  './images/img_460.jpg',
#  './images/img_461.jpg',
#  './images/img_462.jpg',
#  './images/img_463.jpg',
#  './images/img_464.jpg',
#  './images/img_465.jpg',
#  './images/img_466.jpg',
#  './images/img_467.jpg',
#  './images/img_468.jpg',
#  './images/img_469.jpg',
#  './images/img_470.jpg',
#  './images/img_471.jpg',
#  './images/img_472.jpg',
#  './images/img_473.jpg',
#  './images/img_474.jpg',
#  './images/img_475.jpg',
#  './images/img_476.jpg',
#  './images/img_477.jpg',
#  './images/img_478.jpg',
#  './images/img_479.jpg',
#  './images/img_480.jpg',
#  './images/img_481.jpg',
#  './images/img_482.jpg',
#  './images/img_483.jpg',
#  './images/img_484.jpg',
#  './images/img_485.jpg',
#  './images/img_486.jpg',
#  './images/img_487.jpg',
#  './images/img_488.jpg',
#  './images/img_489.jpg',
#  './images/img_490.jpg',
#  './images/img_491.jpg',
#  './images/img_492.jpg',
#  './images/img_493.jpg',
#  './images/img_494.jpg',
#  './images/img_495.jpg',
#  './images/img_496.jpg',
#  './images/img_497.jpg',
#  './images/img_498.jpg',
#  './images/img_499.jpg']

# %% [markdown]
# # Step 2: Load in models and vector database, and convert image and text to embeddings

# %%
# Load in Qdrant client
client = QdrantClient(url="http://localhost:6333")
collection_name = "image_db"

# %%
# Load in the model to be used
device = "cuda" if torch.cuda.is_available() else "cpu"

# model_id = ("openai/clip-vit-base-patch32")
# config = CLIPConfig.from_pretrained(model_id)
# config.text_config.max_position_embeddings = 248

model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
# tokenizer = CLIPTokenizer.from_pretrained("openai/clip-vit-base-patch32", config=config)
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# %%
embeddings = []
for path in valid_img_paths:
    try:
        image = Image.open(path).convert("RGB")
        inputs = processor(images=image, return_tensors="pt")
        with torch.no_grad():
            features = model.get_image_features(**inputs)
        # features = features / features.norm(p=2, dim=-1, keepdim=True)
        embeddings.append(features.cpu().numpy().squeeze())
    except Exception as e:
        print(f"Error processing image {path}: {e}")

# %% [markdown]
# # Step 3: Load the embeddings into Qdrant

# %%
collection_name = "image_db"

client = QdrantClient(host="localhost", port=6333)
points = [
    PointStruct(id=idx, vector=vec, payload={})
    for idx, vec in zip(ids, embeddings)
]

client.upsert(collection_name=collection_name, points=points)
# Out:
# UpdateResult(operation_id=0, status=<UpdateStatus.COMPLETED: 'completed'>)

# %% [markdown]
# # Step 4: Recording Metrics

# %%
df_s_captions[:10]
# Out:
#    id                                            img_url  \
# 0   1  https://thumbs.dreamstime.com/b/car-riding-wet...
# 1   2  https://images.pexels.com/photos/770224/pexels...
# 2   3  https://filmfare.wwmindia.com/content/2017/jul...
# 3   4  https://southernersays.com/wp-content/uploads/...
# 4   5  https://i.pinimg.com/originals/9a/f5/a6/9af5a6...
# 5   6  https://themaydan.com/wp-content/uploads/2019/...
# 6   7  https://i.pinimg.com/originals/ae/f4/f3/aef4f3...
# 7   8  https://photogallery.indiatimes.com/photo/6551...
# 8   9  https://images.squarespace-cdn.com/content/v1/...
# 9  10  https://slideplayer.com/slide/13821916/85/imag...
#
#                                     original_caption  \
# 0  Car riding on wet street. Car driving on wet c...
# 1                         Water Coming Out Of A Pipe
# 2  MARCH 2009 ''It's sad that a boy and girl can ...
# 3         Humpback Whale tail in the Bay of Banderas
# 4  The gaming Team logo of team DUO Team Logo, My...
# 5  Tea, chilies, and takeaway: what food choices ...
# 6  The Bath Co. Camberley satin grey vanity unit ...
# 7          Celebs attend the launch of a style store
# 8  Europe always amazes me on how well their arch...
# 9                       The Development of the Court
#
#                                  paraphrased_caption
# 0            Vehicle driving on a rainy city street.
# 1                        Water spilling from a pipe.
# 2  MARCH 2009 'It's unfortunate that a boy and gi...
# 3            Humpback whale fin in the Banderas Bay.
# 4      DUO Team logo design featuring gaming themes.
# 5  Tea, chilies, and takeout: insights into Briti...
# 6  The Bath Co. Camberley satin grey vanity unit ...
# 7  Celebrities grace the opening of a fashion store.
# 8  I'm always impressed by how Europe's architect...
# 9                         The Evolution of the Court

# %%
avg_mrr = iterate_ds(10, df_s_captions, "mrr", processor, model, "original_caption", client, collection_name, device)
print(avg_mrr)
# Out:
# 0.8386018067881796

# %%
avg_recall_at_1 = iterate_ds(1, df_s_captions, "recall@k", processor, model, "original_caption", client, collection_name, device)
print(avg_recall_at_1)
# Out:
# 0.7835671342685371

# %%
avg_recall_at_5 = iterate_ds(5, df_s_captions, "recall@k", processor, model, "original_caption", client, collection_name, device)
print(avg_recall_at_5)
# Out:
# 0.9118236472945892

# %%
avg_recall_at_10 = iterate_ds(10, df_s_captions, "recall@k", processor, model, "original_caption", client, collection_name, device)
print(avg_recall_at_10)
# Out:
# 0.9438877755511023

# %% [markdown]
# # Step 5: Visualise Results

# %%
# to visualise results, we need to plot the distances between embeddings. We thus need to calculate textual embeddings

og_captions =[i for i in df_s_captions["original_caption"]]
inputs = processor(text=og_captions, return_tensors="pt", padding=True, truncation=True)

# convert into a dictionary to tell to pass intput to device
inputs = {k: v.to(device) for k, v in inputs.items()}

with torch.no_grad():
    text_embeddings = model.get_text_features(**inputs)

# %%
len(text_embeddings)
# Out:
# 499

# %%
## NOTE: ADD SPECTRAL EMBEDDING DISTANCES
# retrieved from the following paper: https://arxiv.org/pdf/2505.03703
distance = cosine_distances
distances = distance(embeddings, text_embeddings)
gt_distances = np.diag(distances)
global_mean = np.mean(distances)
plt.hist(gt_distances, bins=30, alpha=0.5, label="original embeddings", color='blue')
plt.axvline(global_mean, color='blue', linestyle='dashed', linewidth=2,
        label=f'mean text-image distance')

# %%
def visualize_embeddings_pca(image_embeddings: np.ndarray, text_embeddings: np.ndarray, dimensions=2):
    """
    Visualizes the distance between image and text embeddings using PCA.

    Args:
        image_embeddings - numpy array: Array of shape (N, D) for image features
        text_embeddings - numpy array: Array of shape (N, D) for text features
        dimensions - int: Number of dimensions for the graph. Can be either 2 or 3
    Returns:
        None
    """

    # stack all the embeddings so we can perform PCA
    combined = np.vstack([image_embeddings, text_embeddings])
    # perform PCA
    pca = PCA(n_components=dimensions)
    reduced = pca.fit_transform(combined)

    # differentiate between image and text embeddings 
    n = image_embeddings.shape[0]
    img_points = reduced[:n]
    txt_points = reduced[n:]

    # draw a 2d graph if dimensions are 2 and if not, we draw a 3D graph
    if dimensions == 2:
        # create a scatter plot
        plt.figure(figsize=(10, 8))
        plt.scatter(img_points[:, 0], img_points[:, 1], c='blue', label='Images', alpha=0.6)
        plt.scatter(txt_points[:, 0], txt_points[:, 1], c='red', label='Captions', alpha=0.6)

        # draw lines to visualise between each embedding
        for i in range(n):
            plt.plot([img_points[i, 0], txt_points[i, 0]],
                    [img_points[i, 1], txt_points[i, 1]],
                    c='gray', linestyle='--', linewidth=0.5)
            plt.xlabel("PCA 1")
            plt.ylabel("PCA 2")
    elif dimensions == 3:
        fig = plt.figure(figsize=(12, 9))
        ax = fig.add_subplot(111, projection='3d')

        # Scatter plot
        ax.scatter(img_points[:, 0], img_points[:, 1], img_points[:, 2], c='blue', label='Images', alpha=0.7)
        ax.scatter(txt_points[:, 0], txt_points[:, 1], txt_points[:, 2], c='red', label='Captions', alpha=0.7)

        # Draw lines between matching pairs
        for i in range(n):
            ax.plot(
                [img_points[i, 0], txt_points[i, 0]],
                [img_points[i, 1], txt_points[i, 1]],
                [img_points[i, 2], txt_points[i, 2]],
                c='gray', linestyle='--', linewidth=0.5
            )
        ax.set_ylabel("PCA 2")
        ax.set_xlabel("PCA 1")
        ax.set_zlabel("PCA 3")
        

    plt.title("PCA Visualization of Image and Text Embeddings")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# convert outer list which stores numpy arrays into a numpy array
img_embeddings_np = np.stack(embeddings)
text_embeddings_np = np.stack(text_embeddings)

# %%
visualize_embeddings_pca(img_embeddings_np, text_embeddings_np, 2)

# %%
visualize_embeddings_pca(img_embeddings_np, text_embeddings_np, 3)
